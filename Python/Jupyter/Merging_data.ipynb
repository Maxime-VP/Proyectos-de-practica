# %% [markdown]
# # Merge Data
#
#
# pandas.dataframe.merge

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("lukebarousse/data_jobs")
df = ds["train"].to_pandas()
df.head(1)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
#
#     job_location          job_via job_schedule_type  job_work_from_home  \
# 0  Watertown, CT  via Work Nearby         Full-time               False
#
#         search_location      job_posted_date  job_no_degree_mention  \
# 0  Texas, United States  2023-06-16 13:44:15                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
#
#    salary_hour_avg          company_name job_skills job_type_skills
# 0              NaN  Boehringer Ingelheim       None            None

# %%
df_usa = df[(df["job_country"] == "United States")].copy()

# %%
df_usa["job_posted_date"] = pd.to_datetime(df_usa["job_posted_date"])
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 206292 entries, 0 to 785705
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        206292 non-null  object
#  1   job_title              206292 non-null  object
#  2   job_location           205505 non-null  object
#  3   job_via                206285 non-null  object
#  4   job_schedule_type      205099 non-null  object
#  5   job_work_from_home     206292 non-null  bool
#  6   search_location        206292 non-null  object
#  7   job_posted_date        206292 non-null  datetime64[ns]
#  8   job_no_degree_mention  206292 non-null  bool
#  9   job_health_insurance   206292 non-null  bool
#  10  job_country            206292 non-null  object
#  11  salary_rate            25372 non-null   object
#  12  salary_year_avg        15766 non-null   float64
#  13  salary_hour_avg        9405 non-null    float64
# ...

# %%
df_usa.sort_values(by="job_posted_date", inplace=True)
df_usa.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
df_usa["job_posted_month"] = df_usa["job_posted_date"].dt.strftime("%B")
df_usa.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
df_usa_pivot_table = df_usa.pivot_table(index="job_posted_month", columns="job_title_short", aggfunc="size")
df_usa_pivot_table.reset_index(inplace=True)

# %%
df_usa_pivot_table["month_num"] = pd.to_datetime(df_usa_pivot_table["job_posted_month"], format="%B").dt.month

# %%
df_usa_pivot_table
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_usa_pivot_table.sort_values(by="month_num", inplace=True)
df_usa_pivot_table.set_index("job_posted_month", inplace=True)
df_usa_pivot_table
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_software = pd.read_csv("https://lukeb.co/software_csv")

# %%
df_software
# Out:
#    job_posted_month  Front-End Developer  Back-End Developer  \
# 0           January                13619                9827
# 1          February                11456                9116
# 2             March                11102                8178
# 3             April                14037                9209
# 4               May                12126                8864
# 5              June                12003                8065
# 6              July                11914                8061
# 7            August                11571                8191
# 8         September                14016                8447
# 9           October                11419                8476
# 10         November                13771                9034
# 11         December                14033                9232
#
#     Full-Stack Developer  UI/UX Designer
# 0                   5108            4348
# 1                   7298            4284
# 2                   5814            4159
# ...

# %%
df_software.set_index("job_posted_month", inplace=True)
df_software
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %% [markdown]
# # Join

# %%
joined_df = df_usa_pivot_table.join(df_software, on="job_posted_month", how="inner")

# %%
joined_df
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %% [markdown]
# # Merge

# %%
df_merged = df_usa_pivot_table.merge(df_software, on="job_posted_month", how="inner")
df_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_5 = (
    df_merged
    .sum()
    .sort_values(ascending=False)
    .head()
    .index
    .to_list())
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'Data Analyst',
#  'Data Scientist']

# %%
df_merged[top_5].plot(kind="line", figsize=(20,6), ylim=(0,20000), xlabel="2023")
# Out:
# <Axes: xlabel='2023'>

# %% [markdown]
# # Monthly job demand by month

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("lukebarousse/data_jobs")
df = ds["train"].to_pandas()
df.head(1)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
#
#     job_location          job_via job_schedule_type  job_work_from_home  \
# 0  Watertown, CT  via Work Nearby         Full-time               False
#
#         search_location      job_posted_date  job_no_degree_mention  \
# 0  Texas, United States  2023-06-16 13:44:15                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
#
#    salary_hour_avg          company_name job_skills job_type_skills
# 0              NaN  Boehringer Ingelheim       None            None

# %%
df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df_sorted = df.sort_values(by="job_posted_date", ascending=True)
df_sorted.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# 96906                False  New York, United States 2023-01-01 00:00:07
# 98438                False  New York, United States 2023-01-01 00:00:22
# 110290               False  New York, United States 2023-01-01 00:00:24
# 72158                False  New York, United States 2023-01-01 00:00:27
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 108804                  False                 False  United States
# 96906                    True                 False  United States
# 98438                   False                  True  United States
# 110290                  False                 False  United States
# 72158                   False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 108804        None              NaN              NaN    Metasys Technologies
# 96906         None              NaN              NaN            Diverse Lynx
# 98438         None              NaN              NaN              Guidehouse
# 110290        None              NaN              NaN                 Protask
# 72158         None              NaN              NaN  Atria Wealth Solutions
#
#                                                job_skills  \
# 108804  ['sql', 'snowflake', 'visio', 'jira', 'conflue...
# 96906                               ['sql', 'sas', 'sas']
# 98438   ['sql', 'python', 'r', 'azure', 'snowflake', '...
# 110290                                    ['sql', 'jira']
# 72158                        ['sql', 'atlassian', 'jira']
#
#                                           job_type_skills
# 108804  {'analyst_tools': ['visio'], 'async': ['jira',...
# 96906   {'analyst_tools': ['sas'], 'programming': ['sq...
# 98438   {'analyst_tools': ['tableau', 'excel'], 'cloud...
# 110290        {'async': ['jira'], 'programming': ['sql']}
# 72158   {'async': ['jira'], 'other': ['atlassian'], 'p...

# %%
df_sorted["month"] = df_sorted["job_posted_date"].dt.month

# %%
df_sorted.sample(12)
# Out:
#           job_title_short                                          job_title  \
# 97201        Data Analyst                                       DATA ANALYST
# 633625  Software Engineer                                  Solution Engineer
# 489049       Data Analyst                            Data Governance Analyst
# 198404      Data Engineer                                      Data Engineer
# 493565       Data Analyst                              Workflow Data Analyst
# 12539       Data Engineer                           Data Engineer SQL/Python
# 244026     Data Scientist                             Data Science Jr Remoto
# 763605     Cloud Engineer                             Senior Mobile Engineer
# 392006       Data Analyst  Data Analyst. Job in Lebanon My Valley Jobs Today
# 645210      Data Engineer                           Data (Platform) Engineer
# 623842      Data Engineer                         Google Cloud Data Engineer
# 594748     Data Scientist                                     Data Scientist
#
#                             job_location                   job_via  \
# 97201   Hanoi, Hoàn Kiếm, Hanoi, Vietnam               via HR1Tech
# 633625                  Lisbon, Portugal              via LinkedIn
# 489049                  Lisbon, Portugal              via LinkedIn
# 198404       Bengaluru, Karnataka, India              via LinkedIn
# 493565      Blackbrook, Saint Helens, UK                 via BeBee
# 12539                         Mobile, AL                 via BeBee
# 244026                            Mexico                 via BeBee
# 763605                       Philippines           via Trabajo.org
# 392006                       Lebanon, IN  via My Valley Jobs Today
# 645210              Haarlem, Netherlands              via LinkedIn
# 623842                Maharashtra, India                 via Shine
# 594748                       Chicago, IL           via Trabajo.org
#
#        job_schedule_type  job_work_from_home          search_location  \
# 97201          Full-time               False                  Vietnam
# 633625         Full-time               False                 Portugal
# 489049         Full-time               False                 Portugal
# 198404         Full-time               False                    India
# 493565         Full-time               False           United Kingdom
# 12539          Temp work               False  New York, United States
# 244026         Full-time               False                   Mexico
# 763605         Full-time               False              Philippines
# 392006         Full-time               False  Illinois, United States
# 645210         Full-time               False              Netherlands
# 623842         Full-time               False                    India
# 594748         Full-time               False  Illinois, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 97201  2023-07-13 00:18:56                   True                 False
# 633625 2023-12-20 12:26:07                   True                 False
# 489049 2023-11-07 11:41:15                  False                 False
# 198404 2023-10-11 15:11:08                  False                 False
# 493565 2023-10-03 11:09:33                   True                 False
# 12539  2023-11-10 13:24:07                  False                 False
# 244026 2023-11-03 07:09:53                  False                 False
# 763605 2023-04-23 20:16:58                  False                 False
# 392006 2023-05-10 18:02:22                   True                 False
# 645210 2023-11-03 12:49:32                   True                 False
# 623842 2023-12-03 12:05:38                  False                 False
# 594748 2023-05-26 09:04:31                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 97201          Vietnam        None              NaN              NaN
# 633625        Portugal        None              NaN              NaN
# 489049        Portugal        None              NaN              NaN
# 198404           India        None              NaN              NaN
# 493565  United Kingdom        None              NaN              NaN
# 12539    United States        None              NaN              NaN
# 244026          Mexico        None              NaN              NaN
# 763605     Philippines        None              NaN              NaN
# 392006   United States        None              NaN              NaN
# 645210     Netherlands        None              NaN              NaN
# 623842           India        None              NaN              NaN
# 594748   United States        None              NaN              NaN
#
#                               company_name  \
# 97201                              Synodus
# 633625                         SingleStore
# 489049                     BNP Paribas CIB
# 198404                     Koch Industries
# 493565  Rise Technical Recruitment Limited
# 12539                       LeadStack Inc.
# 244026      Northware Software Development
# 763605            Michael Page Philippines
# 392006                         Festool USA
# 645210                       Eminent Groep
# 623842              Zorba Consulting India
# 594748                              Truleo
#
#                                                job_skills  \
# 97201                                                None
# 633625  ['sql', 'python', 'scala', 'java', 'aws', 'azu...
# 489049                                               None
# 198404  ['python', 'bash', 'sql', 'aws', 'redshift', '...
# 493565                              ['excel', 'power bi']
# 12539   ['python', 'sql', 'sql server', 'azure', 'data...
# 244026                                  ['python', 'sql']
# 763605                     ['javascript', 'react', 'git']
# 392006                                            ['sap']
# 645210                        ['aws', 'snowflake', 'sap']
# 623842     ['python', 'java', 'shell', 'hadoop', 'spark']
# 594748                                         ['python']
#
#                                           job_type_skills  month
# 97201                                                None      7
# 633625  {'cloud': ['aws', 'azure', 'gcp', 'vmware'], '...     12
# 489049                                               None     11
# 198404  {'cloud': ['aws', 'redshift', 'snowflake'], 'l...     10
# 493565           {'analyst_tools': ['excel', 'power bi']}     10
# 12539   {'analyst_tools': ['tableau', 'power bi', 'cog...     11
# 244026                 {'programming': ['python', 'sql']}     11
# 763605  {'libraries': ['react'], 'other': ['git'], 'pr...      4
# 392006                         {'analyst_tools': ['sap']}      5
# 645210  {'analyst_tools': ['sap'], 'cloud': ['aws', 's...     11
# 623842  {'libraries': ['hadoop', 'spark'], 'programmin...     12
# 594748                        {'programming': ['python']}      5

# %%
df_pivot = df_sorted.pivot_table(index="month", values="job_title_short", aggfunc="count")
df_pivot
# Out:
#        job_title_short
# month
# 1                91822
# 2                64578
# 3                64084
# 4                62919
# 5                52104
# 6                61572
# 7                63777
# 8                75162
# 9                62359
# 10               66611
# 11               64450
# 12               56303

# %%
df_pivot.plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
unique_jobs = df_sorted["job_title_short"].unique()
unique_jobs
# Out:
# array(['Data Analyst', 'Senior Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Senior Data Engineer', 'Data Scientist',
#        'Senior Data Scientist', 'Machine Learning Engineer',
#        'Software Engineer', 'Cloud Engineer'], dtype=object)

# %%
df_grouped = df_sorted.groupby(["month","job_title_short"]).size()
df_grouped
# Out:
# month  job_title_short
# 1      Business Analyst              4874
#        Cloud Engineer                1295
#        Data Analyst                 23585
#        Data Engineer                21419
#        Data Scientist               20760
#                                     ...
# 12     Machine Learning Engineer     1254
#        Senior Data Analyst           1799
#        Senior Data Engineer          2878
#        Senior Data Scientist         2431
#        Software Engineer             3841
# Length: 120, dtype: int64

# %%
df_grouped_jan = df_grouped.loc[1]

# %%
df_grouped_jan.plot(kind="bar", title="January jobs", xlabel="")
# Out:
# <Axes: title={'center': 'January jobs'}>

# %%
df_grouped_dic = df_grouped.loc[12]

# %%
df_grouped_dic.plot(kind="bar", title="December jobs", xlabel="")
# Out:
# <Axes: title={'center': 'December jobs'}>

# %%
df_grouped_Data_Analyst = df_grouped.loc[
    (slice(None), "Data Analyst")
]

# %%
df_grouped_Data_Analyst.plot(kind="bar")
# Out:
# <Axes: xlabel='month'>
